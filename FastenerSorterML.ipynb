# %% [markdown]
# Step 1: need to install ultralytics on server

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.2/922.2 kB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# Object Detection model (training mode)

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/EE175/fastener2-9/data.yaml epochs=50 imgsz=640 batch=8 #change data source depending on location. since I mounted my google drive to the notebook, I was able to port the dataset from google drive cloud
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 100MB/s]
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# Predicting
#
# note: need to run training model prior to prediction

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/EE175/detect/train/weights/best.pt source=/content/drive/MyDrive/EE175/fastener2-9/test/images save=True
# Out:
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/85 /content/drive/MyDrive/EE175/fastener2-9/test/images/111_jpg.rf.5f271ae005a09dbc7de6a853e8823647.jpg: 640x640 1 screw, 9.3ms
# image 2/85 /content/drive/MyDrive/EE175/fastener2-9/test/images/131_jpg.rf.b4649413ecc913ece1f167c7864736d2.jpg: 640x480 1 screw, 33.5ms
# image 3/85 /content/drive/MyDrive/EE175/fastener2-9/test/images/153_jpg.rf.7330a0f8e2de75b8688646882f5759ff.jpg: 640x480 1 screw, 6.7ms
# image 4/85 /content/drive/MyDrive/EE175/fastener2-9/test/images/155_jpg.rf.e4e42e3766492c9b435cc5f073be5831.jpg: 640x480 1 screw, 6.7ms
# image 5/85 /content/drive/MyDrive/EE175/fastener2-9/test/images/170_jpg.rf.46e71696fd5e6288ddc637c6d47a2ba1.jpg: 640x480 1 screw, 6.5ms
# image 6/85 /content/drive/MyDrive/EE175/fastener2-9/test/images/173_jpg.rf.bbc10edb710fdc4834c6765aa1f0937e.jpg: 640x480 1 screw, 6.7ms
# ...

# %% [markdown]
# After training, a model (.../best.pt) is created. Download the model to use locally.
